# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = "Police Arrest Data.csv"
df = pd.read_csv(file_path)

zone_counts = df["INCIDENTZONE"].value_counts()

most_zone = zone_counts.idxmax()
most_count = zone_counts.max()
least_zone = zone_counts.idxmin()
least_count = zone_counts.min()

print("The Zone that has most police arrest:", most_zone, "(", most_count, ")")
print("The Zone that has least police arrest:", least_zone, "(", least_count, ")")

plt.figure(figsize=(15, 5))
zone_counts.plot(kind="bar")
plt.xlabel("Zone")
plt.ylabel("Arrest")
plt.title("Police Arrest Data")

max_index = neighborhood_counts.index.get_loc(most_neighborhood)
min_index = neighborhood_counts.index.get_loc(least_neighborhood)
plt.show()
# Out:
# The Zone that has most police arrest: 1 ( 14389 )
# The Zone that has least police arrest: OSC ( 450 )

# %%
file_path = "Police Arrest Data.csv"
df = pd.read_csv(file_path)

police_df = df[df["INCIDENTZONE"].str.contains("", case=False, na=False)]

neighborhood_counts = police_df["INCIDENTNEIGHBORHOOD"].value_counts()

most_neighborhood = neighborhood_counts.idxmax()
most_count = neighborhood_counts.max()
least_neighborhood = neighborhood_counts.idxmin()
least_count = neighborhood_counts.min()

print("The Area that has most police arrest:", most_neighborhood, "(", most_count, ")")
print("The Area that has least police arrest:", least_neighborhood, "(", least_count, ")")

plt.figure(figsize=(15, 5))
neighborhood_counts.plot(kind="bar")
plt.xlabel("Neighborhood")
plt.ylabel("Arrest")
plt.title("Police Arrest Data")

max_index = neighborhood_counts.index.get_loc(most_neighborhood)
min_index = neighborhood_counts.index.get_loc(least_neighborhood)
plt.show()
# Out:
# The Area that has most police arrest: Central Business District ( 4440 )
# The Area that has least police arrest: Mt. Oliver Neighborhood ( 2 )
