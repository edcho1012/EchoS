# %% [markdown]
# # **Data For Fire Incident**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Load the Fire Incidents CSV file
fire_df = pd.read_csv("Fire Incidents.csv")

# 2. Preprocess the 'neighborhood' column: convert to string, strip whitespace, and convert to lowercase
fire_df['neighborhood'] = fire_df['neighborhood'].astype(str).str.strip().str.lower()

# 3. Aggregate fire incident counts by neighborhood (in descending order)
fire_counts = fire_df['neighborhood'].value_counts().sort_values(ascending=False).reset_index()
fire_counts.columns = ['neighborhood', 'fire_count']
print(fire_counts)
# 4. Select the bottom 20 neighborhoods and sort them in ascending order by fire incident count
bottom20 = fire_counts.tail(20).sort_values(by='fire_count', ascending=True)

# 5. Create the bar chart (single bar chart)
plt.figure(figsize=(12, 6))
bars = plt.bar(bottom20['neighborhood'], bottom20['fire_count'], color='#003594')

plt.title("Bottom 20 Neighborhoods by Fire Incident Count in Pittsburgh")
plt.xlabel("Neighborhood")
plt.ylabel("Fire Incident Count")
plt.xticks(rotation=45, ha='right')

# Optionally, annotate each bar with the actual fire count
for i, bar in enumerate(bars):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.1,
             str(height), ha='center', va='bottom')

plt.tight_layout()
plt.show()
# Out:
#                  neighborhood  fire_count
# 0                         nan        1658
# 1                     carrick         317
# 2            south side flats         304
# 3   central business district         297
# 4         squirrel hill south         272
# ..                        ...         ...
# 87                  ridgemont          12
# 88                 mt. oliver          12
# 89              east carnegie          11
# 90              regent square           9
# 91       mount oliver borough           7
#
# [92 rows x 2 columns]

# %% [markdown]
# My next dataset was the fire incidents. Similar to traffic I coded to go down the list and count for each neighborhood of how frequent they appear as they were reported an fire incident. And the graph shows the 20 neighborhoods with the least fire incident because obviously less fire brings better and safer neighborhoods.
