# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Load the City Traffic Signs CSV file
traffic_df = pd.read_csv("City Traffic Signs.csv")

# Print the column names to ensure that "neighborhood" exists
print("City Traffic Signs CSV columns:", traffic_df.columns.tolist())

# 2. Preprocess the 'neighborhood' column: convert to string, strip extra spaces, and convert to lower-case
traffic_df['neighborhood'] = traffic_df['neighborhood'].astype(str).str.strip().str.lower()

# 3. Aggregate traffic sign counts by neighborhood
traffic_counts = traffic_df['neighborhood'].value_counts().sort_values(ascending=False).reset_index()
traffic_counts.columns = ['neighborhood', 'traffic_sign_count']

# Display the top 20 neighborhoods for verification
top20 = traffic_counts.head(20)
print("Top 20 Neighborhoods with Most Traffic Signs:")
print(top20)

# 4. Create a bar chart for the top 20 neighborhoods
plt.figure(figsize=(12, 8))
plt.bar(top20['neighborhood'], top20['traffic_sign_count'], color='green')
plt.xlabel("Neighborhood")
plt.ylabel("Traffic Sign Count")
plt.title("Top 20 Neighborhoods with Most Traffic Signs")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# City Traffic Signs CSV columns: ['_id', 'id', 'mutcd_code', 'address_number', 'street', 'city', 'mounting_fixture', 'date_installed', 'description', 'neighborhood', 'council_district', 'ward', 'tract', 'public_works_division', 'pli_division', 'police_zone', 'fire_zone', 'latitude', 'longitude']
# Top 20 Neighborhoods with Most Traffic Signs:
#                  neighborhood  traffic_sign_count
# 0            south side flats                3672
# 1                  bloomfield                3627
# 2   central business district                3491
# 3                   shadyside                3370
# 4         squirrel hill south                3281
# 5                   brookline                2256
# 6                     carrick                2044
# 7       central lawrenceville                1970
# 8         squirrel hill north                1895
# 9                east liberty                1759
# 10              north oakland                1743
# ...
